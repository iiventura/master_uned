# %% [markdown]
# # Práctica 1: Irene J. Ventura Farias
#
# ## Ejercicio 2: Hive
#
# ## Parte I
#
# En este trabajo se van a utilizar ficheros dos ficheros que contienen los siguientes campos:
# - __authors.csv__: author_id; author_name.
# - __datasets.csv__: title; author_id; bestsellers-rank; imprint; publication-date;rating-avg; rating-count
#
# Partiendo de este dataset, desarrolla las órdenes de HiveQL que implementen las
# siguientes tareas.

# %%
#creamos un directorio para tratar los ficheros que vayamos generando y usando en local
! mkdir -p hive1
import os
os.chdir("hive1")

# %%
! pwd #Comprobamos que estamos en la ruta creada
# Out:
# /media/notebooks/hive1

# %%
# !ls ../hive1 #Comprobamos que los ficheros estan cargados en local
# Out:
# authors.csv  dataset.csv

# %%
 #Creamos los directorios en HDFS
! hadoop fs -mkdir /user/root/hive1 #Ruta principal
! hadoop fs -mkdir /user/root/hive1/authors #Ruta fichero authors.csv
! hadoop fs -mkdir /user/root/hive1/dataset #Ruta fichero dataset.csv

# %%
# Copiamos los ficheros a HDFS a sus respectivos directorios
! hadoop fs -put ../hive1/authors.csv /user/root/hive1/authors/
! hadoop fs -put ../hive1/dataset.csv /user/root/hive1/dataset/
# Confirmamos que se hayan cargado previamente 
! hadoop fs -ls /user/root/hive1/authors/
! hadoop fs -ls /user/root/hive1/dataset/
# Out:
# Found 1 items
# -rw-r--r--   3 root supergroup     464036 2021-11-14 11:02 /user/root/hive1/authors/authors.csv
# Found 1 items
# -rw-r--r--   3 root supergroup    3391054 2021-11-14 11:02 /user/root/hive1/dataset/dataset.csv

# %% [markdown]
# __1. Crea las tablas necesarias para almacenar datos. Pueden ser internas o externas en función de los datos que se desee. La decisión de interna o externa debe estar razonada.__
#
# He decidido realizar las dos tablas como externas, ya que el ejercicio se trata de hacer consultas de los datos y  no hay que  realizar modificaciones. Por lo que se hará referencia en la consulta sobre sus correspondientes archivos HDFS.
#
# - Para ambas tablas se les ha asignado el parámetro *"skip.header.line.count"*, de forma que al cargar los datos sobre las tablas ignora las cabeceras de los ficheros.

# %%
# %%writefile createHiveEj2.hql
#
# -- Creamos la BD
# CREATE DATABASE IF NOT EXISTS ej2_p1;
#
# -- Nos aseguramos de usar la BD creada
# USE ej2_p1;
#
# -- Creamos las tablas externas
# -- **AUTORES**
# CREATE EXTERNAL TABLE IF NOT EXISTS authors
#  (author_id  INT,
#   author_name  STRING)
# ROW FORMAT DELIMITED FIELDS TERMINATED BY '\;'
# LOCATION '/user/root/hive1/authors'
# TBLPROPERTIES ("skip.header.line.count"="1");
#
# -- **LIBROS**
# CREATE EXTERNAL TABLE IF NOT EXISTS dataset (
#   title  STRING,
#   author_id  INT,
#   bestseller_rank  INT,
#   imprint  STRING,
#   publication_date STRING,
#   rating_avg  FLOAT,
#   rating_count INT)
# ROW FORMAT DELIMITED FIELDS TERMINATED BY '\;'
# LOCATION '/user/root/hive1/dataset'
# TBLPROPERTIES ("skip.header.line.count"="1");
#
# --Comprobamos que se hayan creado las tablas correctamente
# SHOW TABLES;
# DESCRIBE authors;
# DESCRIBE dataset;
# Out:
# Overwriting createHiveEj2.hql

# %%
! beeline -u "jdbc:hive2://localhost:10000/" -f createHiveEj2.hql
# Out:
# Connecting to jdbc:hive2://localhost:10000/
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://localhost:10000/>
# 0: jdbc:hive2://localhost:10000/> -- Creamos la BD
# 0: jdbc:hive2://localhost:10000/> CREATE DATABASE IF NOT EXISTS ej2_p1;
# INFO  : Compiling command(queryId=root_20211114111528_33bd6692-96de-4a2c-a9e1-48e9e9141b95): CREATE DATABASE IF NOT EXISTS ej2_p1
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=root_20211114111528_33bd6692-96de-4a2c-a9e1-48e9e9141b95); Time taken: 5.064 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114111528_33bd6692-96de-4a2c-a9e1-48e9e9141b95): CREATE DATABASE IF NOT EXISTS ej2_p1
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114111528_33bd6692-96de-4a2c-a9e1-48e9e9141b95); Time taken: 1.227 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (8.05 seconds)
# 0: jdbc:hive2://localhost:10000/>
# 0: jdbc:hive2://localhost:10000/> -- Nos aseguramos de usar la BD creada
# 0: jdbc:hive2://localhost:10000/> USE ej2_p1;
# INFO  : Compiling command(queryId=root_20211114111536_b98eaf6d-81e0-4baf-9704-18be0e390546): USE ej2_p1
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=root_20211114111536_b98eaf6d-81e0-4baf-9704-18be0e390546); Time taken: 0.184 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114111536_b98eaf6d-81e0-4baf-9704-18be0e390546): USE ej2_p1
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114111536_b98eaf6d-81e0-4baf-9704-18be0e390546); Time taken: 0.207 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.565 seconds)
# 0: jdbc:hive2://localhost:10000/>
# 0: jdbc:hive2://localhost:10000/> -- Creamos las tablas externas
# 0: jdbc:hive2://localhost:10000/> -- **AUTORES**
# 0: jdbc:hive2://localhost:10000/> CREATE EXTERNAL TABLE IF NOT EXISTS authors
# . . . . . . . . . . . . . . . . >  (author_id  INT,
# . . . . . . . . . . . . . . . . >   author_name  STRING)
#   . . . . . . . . . . . . . . . > ROW FORMAT DELIMITED FIELDS TERMINATED BY '\;'
# . . . . . . . . . . . . . . . . > LOCATION '/user/root/hive1/authors'
# . . . . . . . . . . . . . . . . > TBLPROPERTIES ("skip.header.line.count"="1");
# INFO  : Compiling command(queryId=root_20211114111537_25e3366a-5ebf-4d6f-9571-e260b63d0874): CREATE EXTERNAL TABLE IF NOT EXISTS authors
# (author_id  INT,
# author_name  STRING)
# ROW FORMAT DELIMITED FIELDS TERMINATED BY '\;'
# LOCATION '/user/root/hive1/authors'
# TBLPROPERTIES ("skip.header.line.count"="1")
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=root_20211114111537_25e3366a-5ebf-4d6f-9571-e260b63d0874); Time taken: 1.549 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114111537_25e3366a-5ebf-4d6f-9571-e260b63d0874): CREATE EXTERNAL TABLE IF NOT EXISTS authors
# (author_id  INT,
# author_name  STRING)
# ROW FORMAT DELIMITED FIELDS TERMINATED BY '\;'
# LOCATION '/user/root/hive1/authors'
# TBLPROPERTIES ("skip.header.line.count"="1")
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114111537_25e3366a-5ebf-4d6f-9571-e260b63d0874); Time taken: 3.8 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (5.624 seconds)
# 0: jdbc:hive2://localhost:10000/>
# 0: jdbc:hive2://localhost:10000/> -- **LIBROS**
# 0: jdbc:hive2://localhost:10000/> CREATE EXTERNAL TABLE IF NOT EXISTS dataset (
# . . . . . . . . . . . . . . . . >   title  STRING,
# . . . . . . . . . . . . . . . . >   author_id  INT,
# . . . . . . . . . . . . . . . . >   bestseller_rank  INT,
# . . . . . . . . . . . . . . . . >   imprint  STRING,
# . . . . . . . . . . . . . . . . >   publication_date STRING,
# . . . . . . . . . . . . . . . . >   rating_avg  FLOAT,
# . . . . . . . . . . . . . . . . >   rating_count INT)
#   . . . . . . . . . . . . . . . > ROW FORMAT DELIMITED FIELDS TERMINATED BY '\;'
# . . . . . . . . . . . . . . . . > LOCATION '/user/root/hive1/dataset'
# . . . . . . . . . . . . . . . . > TBLPROPERTIES ("skip.header.line.count"="1");
# INFO  : Compiling command(queryId=root_20211114111544_b6bdadce-6c95-4026-8e3f-9030bc12bde0): CREATE EXTERNAL TABLE IF NOT EXISTS dataset (
# title  STRING,
# author_id  INT,
# bestseller_rank  INT,
# imprint  STRING,
# publication_date STRING,
# rating_avg  FLOAT,
# rating_count INT)
# ROW FORMAT DELIMITED FIELDS TERMINATED BY '\;'
# LOCATION '/user/root/hive1/dataset'
# TBLPROPERTIES ("skip.header.line.count"="1")
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=root_20211114111544_b6bdadce-6c95-4026-8e3f-9030bc12bde0); Time taken: 0.281 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114111544_b6bdadce-6c95-4026-8e3f-9030bc12bde0): CREATE EXTERNAL TABLE IF NOT EXISTS dataset (
# title  STRING,
# author_id  INT,
# bestseller_rank  INT,
# imprint  STRING,
# publication_date STRING,
# rating_avg  FLOAT,
# rating_count INT)
# ROW FORMAT DELIMITED FIELDS TERMINATED BY '\;'
# LOCATION '/user/root/hive1/dataset'
# TBLPROPERTIES ("skip.header.line.count"="1")
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114111544_b6bdadce-6c95-4026-8e3f-9030bc12bde0); Time taken: 1.682 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (2.106 seconds)
# 0: jdbc:hive2://localhost:10000/>
# orrectamente2://localhost:10000/> --Comprobamos que se hayan creado las tablas c
# 0: jdbc:hive2://localhost:10000/> SHOW TABLES;
# INFO  : Compiling command(queryId=root_20211114111546_06fe3c16-6a4b-4b7f-bb32-602707be9a87): SHOW TABLES
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:tab_name, type:string, comment:from deserializer)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114111546_06fe3c16-6a4b-4b7f-bb32-602707be9a87); Time taken: 0.998 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114111546_06fe3c16-6a4b-4b7f-bb32-602707be9a87): SHOW TABLES
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114111546_06fe3c16-6a4b-4b7f-bb32-602707be9a87); Time taken: 0.382 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +-----------+
# | tab_name  |
# +-----------+
# | authors   |
# | dataset   |
# +-----------+
# 2 rows selected (3.035 seconds)
# 0: jdbc:hive2://localhost:10000/> DESCRIBE authors;
# INFO  : Compiling command(queryId=root_20211114111550_ccb4a36b-e951-4c36-9ae8-0420e657dc52): DESCRIBE authors
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:col_name, type:string, comment:from deserializer), FieldSchema(name:data_type, type:string, comment:from deserializer), FieldSchema(name:comment, type:string, comment:from deserializer)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114111550_ccb4a36b-e951-4c36-9ae8-0420e657dc52); Time taken: 0.612 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114111550_ccb4a36b-e951-4c36-9ae8-0420e657dc52): DESCRIBE authors
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114111550_ccb4a36b-e951-4c36-9ae8-0420e657dc52); Time taken: 0.74 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +--------------+------------+----------+
# |   col_name   | data_type  | comment  |
# +--------------+------------+----------+
# | author_id    | int        |          |
# | author_name  | string     |          |
# +--------------+------------+----------+
# 2 rows selected (1.77 seconds)
# 0: jdbc:hive2://localhost:10000/> DESCRIBE dataset;
# INFO  : Compiling command(queryId=root_20211114111551_6ec7effa-7d38-40a2-afa5-08dd1ea1b896): DESCRIBE dataset
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:col_name, type:string, comment:from deserializer), FieldSchema(name:data_type, type:string, comment:from deserializer), FieldSchema(name:comment, type:string, comment:from deserializer)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114111551_6ec7effa-7d38-40a2-afa5-08dd1ea1b896); Time taken: 0.484 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114111551_6ec7effa-7d38-40a2-afa5-08dd1ea1b896): DESCRIBE dataset
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114111551_6ec7effa-7d38-40a2-afa5-08dd1ea1b896); Time taken: 0.402 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +-------------------+------------+----------+
# |     col_name      | data_type  | comment  |
# +-------------------+------------+----------+
# | title             | string     |          |
# | author_id         | int        |          |
# | bestseller_rank   | int        |          |
# | imprint           | string     |          |
# | publication_date  | string     |          |
# | rating_avg        | float      |          |
# | rating_count      | int        |          |
# +-------------------+------------+----------+
# 7 rows selected (1.229 seconds)
# 0: jdbc:hive2://localhost:10000/>
# 0: jdbc:hive2://localhost:10000/> Closing: 0: jdbc:hive2://localhost:10000/

# %% [markdown]
# __2. Importa los datos en las tablas creadas.__
#
# Como hemos hecho copia de los csvs a HDFS  previamente, al crear las tablas y asignarle en LOCATION las rutas de HDFS los datos de los csv, se importaron automaticamente. Es por eso que simplemente realizamos consultas simples sobre las tablas a modo de confirmación.

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p1" -e 'SELECT * FROM authors LIMIT 5;'
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p1
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114111648_a88857b0-1b26-4127-9461-925076fc957f): SELECT * FROM authors LIMIT 5
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:authors.author_id, type:int, comment:null), FieldSchema(name:authors.author_name, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114111648_a88857b0-1b26-4127-9461-925076fc957f); Time taken: 14.026 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114111648_a88857b0-1b26-4127-9461-925076fc957f): SELECT * FROM authors LIMIT 5
# INFO  : Completed executing command(queryId=root_20211114111648_a88857b0-1b26-4127-9461-925076fc957f); Time taken: 0.004 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +--------------------+----------------------+
# | authors.author_id  | authors.author_name  |
# +--------------------+----------------------+
# | 3                  | Cecelia Mecca        |
# | 4                  | Ana Maria Spagna     |
# | 5                  | Mark Vanhoenacker    |
# | 6                  | Jen Gale             |
# | 7                  | Giles Chapman        |
# +--------------------+----------------------+
# 5 rows selected (16.703 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p1

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p1" -e 'SELECT * FROM dataset LIMIT 5;'
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p1
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114111826_c5fe563e-cb89-49c9-aceb-e0c4c5d6915e): SELECT * FROM dataset LIMIT 5
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:dataset.title, type:string, comment:null), FieldSchema(name:dataset.author_id, type:int, comment:null), FieldSchema(name:dataset.bestseller_rank, type:int, comment:null), FieldSchema(name:dataset.imprint, type:string, comment:null), FieldSchema(name:dataset.publication_date, type:string, comment:null), FieldSchema(name:dataset.rating_avg, type:float, comment:null), FieldSchema(name:dataset.rating_count, type:int, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114111826_c5fe563e-cb89-49c9-aceb-e0c4c5d6915e); Time taken: 1.694 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114111826_c5fe563e-cb89-49c9-aceb-e0c4c5d6915e): SELECT * FROM dataset LIMIT 5
# INFO  : Completed executing command(queryId=root_20211114111826_c5fe563e-cb89-49c9-aceb-e0c4c5d6915e); Time taken: 0.004 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +----------------------------------------------------+--------------------+--------------------------+------------------+---------------------------+---------------------+-----------------------+
# |                   dataset.title                    | dataset.author_id  | dataset.bestseller_rank  | dataset.imprint  | dataset.publication_date  | dataset.rating_avg  | dataset.rating_count  |
# +----------------------------------------------------+--------------------+--------------------------+------------------+---------------------------+---------------------+-----------------------+
# | The Mercenary : Order of the Broken Blade          | 3                  | 51517                    |                  | 17/09/2019                | 4.49                | 211                   |
# | 100 Skills You'll Need for the End of the World (as We Know It) | 4                  | 162985                   |                  | 05/05/2015                | 2.96                | 139                   |
# | How to Land a Plane                                | 5                  | 41520                    |                  | 21/09/2017                | 4.21                | 158                   |
# | Skyfaring : A Journey with a Pilot                 | 5                  | 870385                   |                  | 03/05/2016                | 3.94                | 2684                  |
# | How to Land a Plane                                | 5                  | 882451                   |                  | 30/04/2019                | 4.21                | 158                   |
# +----------------------------------------------------+--------------------+--------------------------+------------------+---------------------------+---------------------+-----------------------+
# 5 rows selected (3.339 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p1

# %% [markdown]
# __3. Crea una vista sobre las tablas creadas. Esta vista tendrá para cada título, el nombre del autor, fecha de publicación, y valoración media.__

# %%
# %%writefile view1Ej2.hql
#
# -- Creamos las vista
# CREATE VIEW IF NOT EXISTS vista1_ej21
# AS SELECT d.title, a.author_name, d.publication_date, d.rating_avg
# FROM authors a JOIN dataset d
# ON a.author_id = d.author_id;
#
# -- Comprobar que se ha creado la vista
# SHOW VIEWS;
# Out:
# Writing view1Ej2.hql

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p1" -f view1Ej2.hql
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p1
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://localhost:10000/ej2_p1>
# 0: jdbc:hive2://localhost:10000/ej2_p1> -- Creamos las vista
# 0: jdbc:hive2://localhost:10000/ej2_p1> CREATE VIEW IF NOT EXISTS vista1_ej21
# ication_d . . . . . . . . . . . . . . > AS SELECT d.title, a.author_name, d.publ ate, d.rating_avg
# . . . . . . . . . . . . . . . . . . . > FROM authors a JOIN dataset d
# . . . . . . . . . . . . . . . . . . . > ON a.author_id = d.author_id;
# INFO  : Compiling command(queryId=root_20211114112054_addb3038-0218-41c7-b77d-3980f4b6edb3): CREATE VIEW IF NOT EXISTS vista1_ej21
# AS SELECT d.title, a.author_name, d.publication_date, d.rating_avg
# FROM authors a JOIN dataset d
# ON a.author_id = d.author_id
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:title, type:string, comment:null), FieldSchema(name:author_name, type:string, comment:null), FieldSchema(name:publication_date, type:string, comment:null), FieldSchema(name:rating_avg, type:float, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114112054_addb3038-0218-41c7-b77d-3980f4b6edb3); Time taken: 5.756 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114112054_addb3038-0218-41c7-b77d-3980f4b6edb3): CREATE VIEW IF NOT EXISTS vista1_ej21
# AS SELECT d.title, a.author_name, d.publication_date, d.rating_avg
# FROM authors a JOIN dataset d
# ON a.author_id = d.author_id
# INFO  : Starting task [Stage-1:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114112054_addb3038-0218-41c7-b77d-3980f4b6edb3); Time taken: 1.042 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (7.776 seconds)
# 0: jdbc:hive2://localhost:10000/ej2_p1>
# 0: jdbc:hive2://localhost:10000/ej2_p1> -- Comprobar que se ha creado la vista
# 0: jdbc:hive2://localhost:10000/ej2_p1> SHOW VIEWS;
# INFO  : Compiling command(queryId=root_20211114112102_97ab0f6e-545e-48f6-beaa-75984d0439bf): SHOW VIEWS
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:tab_name, type:string, comment:from deserializer)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114112102_97ab0f6e-545e-48f6-beaa-75984d0439bf); Time taken: 0.146 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114112102_97ab0f6e-545e-48f6-beaa-75984d0439bf): SHOW VIEWS
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114112102_97ab0f6e-545e-48f6-beaa-75984d0439bf); Time taken: 0.175 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +--------------+
# |   tab_name   |
# +--------------+
# | vista1_ej21  |
# +--------------+
# 1 row selected (0.95 seconds)
# 0: jdbc:hive2://localhost:10000/ej2_p1>
# 0: jdbc:hive2://localhost:10000/ej2_p1> Closing: 0: jdbc:hive2://localhost:10000/ej2_p1

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p1" -e 'SELECT * FROM vista1_ej21 LIMIT 5;'
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p1
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114112220_3e2c389d-fb66-4dc3-b098-ee85fc7abba0): SELECT * FROM vista1_ej21 LIMIT 5
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:vista1_ej21.title, type:string, comment:null), FieldSchema(name:vista1_ej21.author_name, type:string, comment:null), FieldSchema(name:vista1_ej21.publication_date, type:string, comment:null), FieldSchema(name:vista1_ej21.rating_avg, type:float, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114112220_3e2c389d-fb66-4dc3-b098-ee85fc7abba0); Time taken: 3.532 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114112220_3e2c389d-fb66-4dc3-b098-ee85fc7abba0): SELECT * FROM vista1_ej21 LIMIT 5
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = root_20211114112220_3e2c389d-fb66-4dc3-b098-ee85fc7abba0
# INFO  : Total jobs = 1
# INFO  : Starting task [Stage-4:MAPREDLOCAL] in serial mode
# INFO  : Execution completed successfully
# INFO  : MapredLocal task succeeded
# INFO  : Launching Job 1 out of 1
# INFO  : Starting task [Stage-3:MAPRED] in serial mode
# INFO  : Number of reduce tasks is set to 0 since there's no reduce operator
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0001
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0001/
# INFO  : Starting Job = job_1636883453227_0001, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0001/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0001
# INFO  : Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 0
# INFO  : 2021-11-14 11:24:43,840 Stage-3 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 11:25:38,143 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 11.74 sec
# INFO  : MapReduce Total cumulative CPU time: 11 seconds 740 msec
# INFO  : Ended Job = job_1636883453227_0001
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-3: Map: 1   Cumulative CPU: 11.74 sec   HDFS Read: 698422 HDFS Write: 493 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 11 seconds 740 msec
# INFO  : Completed executing command(queryId=root_20211114112220_3e2c389d-fb66-4dc3-b098-ee85fc7abba0); Time taken: 199.646 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +----------------------------------------------------+--------------------------+-------------------------------+-------------------------+
# |                 vista1_ej21.title                  | vista1_ej21.author_name  | vista1_ej21.publication_date  | vista1_ej21.rating_avg  |
# +----------------------------------------------------+--------------------------+-------------------------------+-------------------------+
# | The Mercenary : Order of the Broken Blade          | Cecelia Mecca            | 17/09/2019                    | 4.49                    |
# | 100 Skills You'll Need for the End of the World (as We Know It) | Ana Maria Spagna         | 05/05/2015                    | 2.96                    |
# | How to Land a Plane                                | Mark Vanhoenacker        | 21/09/2017                    | 4.21                    |
# | Skyfaring : A Journey with a Pilot                 | Mark Vanhoenacker        | 03/05/2016                    | 3.94                    |
# | How to Land a Plane                                | Mark Vanhoenacker        | 30/04/2019                    | 4.21                    |
# +----------------------------------------------------+--------------------------+-------------------------------+-------------------------+
# 5 rows selected (203.867 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p1

# %% [markdown]
# __4.1. Crea las consultas de Hive necesarias para responder las siguientes cuestiones:__
#
#     - ¿Cuál es el título del libro con mejor valoración media del autor Rand McNally?

# %%
#Imprime el primer libro que hay en la bd que tenga rating5 y sea de Rand McNally
# ya que este autor tiene más de un libro con esa valoración
! beeline -u "jdbc:hive2://localhost:10000/ej2_p1" -e "\
SELECT title \
FROM vista1_ej21 \
WHERE author_name = 'Rand McNally'\
ORDER BY rating_avg DESC\
LIMIT 1;"
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p1
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114114341_3b2d5877-e8d1-44a7-a7e0-9b67a8691f5d): SELECT title  FROM vista1_ej21  WHERE author_name = 'Rand McNally' ORDER BY rating_avg DESC LIMIT 1
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:title, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114114341_3b2d5877-e8d1-44a7-a7e0-9b67a8691f5d); Time taken: 3.146 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114114341_3b2d5877-e8d1-44a7-a7e0-9b67a8691f5d): SELECT title  FROM vista1_ej21  WHERE author_name = 'Rand McNally' ORDER BY rating_avg DESC LIMIT 1
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = root_20211114114341_3b2d5877-e8d1-44a7-a7e0-9b67a8691f5d
# INFO  : Total jobs = 1
# INFO  : Starting task [Stage-5:MAPREDLOCAL] in serial mode
# INFO  : Execution completed successfully
# INFO  : MapredLocal task succeeded
# INFO  : Launching Job 1 out of 1
# INFO  : Starting task [Stage-2:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0005
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0005/
# INFO  : Starting Job = job_1636883453227_0005, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0005/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0005
# INFO  : Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 11:45:38,102 Stage-2 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 11:46:27,704 Stage-2 map = 67%,  reduce = 0%, Cumulative CPU 10.62 sec
# INFO  : 2021-11-14 11:46:28,910 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 10.94 sec
# INFO  : 2021-11-14 11:47:11,678 Stage-2 map = 100%,  reduce = 67%, Cumulative CPU 18.08 sec
# INFO  : 2021-11-14 11:47:13,147 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 18.91 sec
# INFO  : MapReduce Total cumulative CPU time: 18 seconds 910 msec
# INFO  : Ended Job = job_1636883453227_0005
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 18.91 sec   HDFS Read: 3408882 HDFS Write: 140 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 18 seconds 910 msec
# INFO  : Completed executing command(queryId=root_20211114114341_3b2d5877-e8d1-44a7-a7e0-9b67a8691f5d); Time taken: 214.123 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +-------------------------------------------+
# |                   title                   |
# +-------------------------------------------+
# | Delorme South Dakota Atlas and Gazetteer  |
# +-------------------------------------------+
# 1 row selected (218.349 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p1

# %% [markdown]
# __4.2. Crea las consultas de Hive necesarias para responder las siguientes cuestiones:__
#
#     - ¿Cuáles son los cinco autores cuyos libros tienen más valoraciones?

# %%
# %%writefile view2Ej2.hql
#
# -- Creamos las vista
# CREATE VIEW IF NOT EXISTS vista2_ej21
#     AS SELECT d.title, a.author_name, d.rating_count
#     FROM authors a JOIN dataset d
#     ON a.author_id = d.author_id;
#
# -- Consultar que se ha creado la vista
# SHOW VIEWS;
# Out:
# Writing view2Ej2.hql

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p1" -f view2Ej2.hql
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p1
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://localhost:10000/ej2_p1>
# 0: jdbc:hive2://localhost:10000/ej2_p1> -- Creamos las vista
# 0: jdbc:hive2://localhost:10000/ej2_p1> CREATE VIEW IF NOT EXISTS vista2_ej21
# rating_count. . . . . . . . . . . . . >     AS SELECT d.title, a.author_name, d.
# . . . . . . . . . . . . . . . . . . . >     FROM authors a JOIN dataset d
# . . . . . . . . . . . . . . . . . . . >     ON a.author_id = d.author_id;
# INFO  : Compiling command(queryId=root_20211114113525_0a604559-f345-47f6-92b0-9274fc3f94db): CREATE VIEW IF NOT EXISTS vista2_ej21
# AS SELECT d.title, a.author_name, d.rating_count
# FROM authors a JOIN dataset d
# ON a.author_id = d.author_id
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:title, type:string, comment:null), FieldSchema(name:author_name, type:string, comment:null), FieldSchema(name:rating_count, type:int, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114113525_0a604559-f345-47f6-92b0-9274fc3f94db); Time taken: 2.563 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114113525_0a604559-f345-47f6-92b0-9274fc3f94db): CREATE VIEW IF NOT EXISTS vista2_ej21
# AS SELECT d.title, a.author_name, d.rating_count
# FROM authors a JOIN dataset d
# ON a.author_id = d.author_id
# INFO  : Starting task [Stage-1:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114113525_0a604559-f345-47f6-92b0-9274fc3f94db); Time taken: 1.191 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (4.464 seconds)
# 0: jdbc:hive2://localhost:10000/ej2_p1>
# 0: jdbc:hive2://localhost:10000/ej2_p1> -- Consultar que se ha creado la vista
# 0: jdbc:hive2://localhost:10000/ej2_p1> SHOW VIEWS;
# INFO  : Compiling command(queryId=root_20211114113529_446ad8e2-10ce-4d19-9824-6136523d5056): SHOW VIEWS
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:tab_name, type:string, comment:from deserializer)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114113529_446ad8e2-10ce-4d19-9824-6136523d5056); Time taken: 0.097 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114113529_446ad8e2-10ce-4d19-9824-6136523d5056): SHOW VIEWS
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114113529_446ad8e2-10ce-4d19-9824-6136523d5056); Time taken: 0.153 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +--------------+
# |   tab_name   |
# +--------------+
# | vista1_ej21  |
# | vista2_ej21  |
# +--------------+
# 2 rows selected (0.689 seconds)
# 0: jdbc:hive2://localhost:10000/ej2_p1>
# 0: jdbc:hive2://localhost:10000/ej2_p1> Closing: 0: jdbc:hive2://localhost:10000/ej2_p1

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p1" -e "\
SELECT author_name\
FROM vista2_ej21 \
GROUP BY author_name \
ORDER BY SUM(rating_count) DESC\
LIMIT 5;"
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p1
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114113702_618ffe69-4652-4923-8417-cfa960fd2b99): SELECT author_name FROM vista2_ej21  GROUP BY author_name  ORDER BY SUM(rating_count) DESC LIMIT 5
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:author_name, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114113702_618ffe69-4652-4923-8417-cfa960fd2b99); Time taken: 4.002 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114113702_618ffe69-4652-4923-8417-cfa960fd2b99): SELECT author_name FROM vista2_ej21  GROUP BY author_name  ORDER BY SUM(rating_count) DESC LIMIT 5
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = root_20211114113702_618ffe69-4652-4923-8417-cfa960fd2b99
# INFO  : Total jobs = 2
# INFO  : Starting task [Stage-6:MAPREDLOCAL] in serial mode
# INFO  : Execution completed successfully
# INFO  : MapredLocal task succeeded
# INFO  : Launching Job 1 out of 2
# INFO  : Starting task [Stage-2:MAPRED] in serial mode
# INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0003
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0003/
# INFO  : Starting Job = job_1636883453227_0003, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0003/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0003
# INFO  : Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 11:38:58,190 Stage-2 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 11:39:50,675 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 11.19 sec
# INFO  : 2021-11-14 11:40:33,695 Stage-2 map = 100%,  reduce = 69%, Cumulative CPU 20.15 sec
# INFO  : 2021-11-14 11:40:38,792 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 23.17 sec
# INFO  : MapReduce Total cumulative CPU time: 23 seconds 170 msec
# INFO  : Ended Job = job_1636883453227_0003
# INFO  : Launching Job 2 out of 2
# INFO  : Starting task [Stage-3:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0004
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0004/
# INFO  : Starting Job = job_1636883453227_0004, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0004/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0004
# INFO  : Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 11:41:42,687 Stage-3 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 11:42:26,717 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 7.58 sec
# INFO  : 2021-11-14 11:43:06,325 Stage-3 map = 100%,  reduce = 73%, Cumulative CPU 14.22 sec
# INFO  : 2021-11-14 11:43:07,595 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 14.83 sec
# INFO  : MapReduce Total cumulative CPU time: 14 seconds 830 msec
# INFO  : Ended Job = job_1636883453227_0004
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 23.17 sec   HDFS Read: 3409980 HDFS Write: 696615 SUCCESS
# INFO  : Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 14.83 sec   HDFS Read: 704251 HDFS Write: 236 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 38 seconds 0 msec
# INFO  : Completed executing command(queryId=root_20211114113702_618ffe69-4652-4923-8417-cfa960fd2b99); Time taken: 365.344 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +---------------------------+
# |        author_name        |
# +---------------------------+
# | J. K. Rowling             |
# | Clive Staples Lewis       |
# | Antoine de Saint-Exupery  |
# | Charles Dickens           |
# | James Herriot             |
# +---------------------------+
# 5 rows selected (370.193 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p1

# %% [markdown]
# __4.3. Crea las consultas de Hive necesarias para responder las siguientes cuestiones:__
#
#     - ¿Cuáles son los dos libros más recientes del autor Rand McNally?
#
# En este caso como hay que ordenar por fecha y este campo lo he tratado como un string, hice la conversion del publication_day para el Order By

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p1" -e "\
SELECT title, publication_date\
FROM vista1_ej21 \
WHERE author_name = 'Rand McNally'\
ORDER BY FROM_UNIXTIME(UNIX_TIMESTAMP(publication_date, 'dd/MM/yyyy')) DESC\
LIMIT 2"
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p1
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114115036_084a398b-4566-4235-afbd-f8374ee81363): SELECT title, publication_date FROM vista1_ej21  WHERE author_name = 'Rand McNally' ORDER BY FROM_UNIXTIME(UNIX_TIMESTAMP(publication_date, 'dd/MM/yyyy')) DESC LIMIT 2
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:title, type:string, comment:null), FieldSchema(name:publication_date, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114115036_084a398b-4566-4235-afbd-f8374ee81363); Time taken: 3.267 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114115036_084a398b-4566-4235-afbd-f8374ee81363): SELECT title, publication_date FROM vista1_ej21  WHERE author_name = 'Rand McNally' ORDER BY FROM_UNIXTIME(UNIX_TIMESTAMP(publication_date, 'dd/MM/yyyy')) DESC LIMIT 2
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = root_20211114115036_084a398b-4566-4235-afbd-f8374ee81363
# INFO  : Total jobs = 1
# INFO  : Starting task [Stage-5:MAPREDLOCAL] in serial mode
# INFO  : Execution completed successfully
# INFO  : MapredLocal task succeeded
# INFO  : Launching Job 1 out of 1
# INFO  : Starting task [Stage-2:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0006
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0006/
# INFO  : Starting Job = job_1636883453227_0006, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0006/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0006
# INFO  : Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 11:52:25,264 Stage-2 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 11:53:14,352 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 10.9 sec
# INFO  : 2021-11-14 11:53:53,571 Stage-2 map = 100%,  reduce = 67%, Cumulative CPU 17.93 sec
# INFO  : 2021-11-14 11:53:56,061 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 18.92 sec
# INFO  : MapReduce Total cumulative CPU time: 18 seconds 920 msec
# INFO  : Ended Job = job_1636883453227_0006
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 18.92 sec   HDFS Read: 3410415 HDFS Write: 230 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 18 seconds 920 msec
# INFO  : Completed executing command(queryId=root_20211114115036_084a398b-4566-4235-afbd-f8374ee81363); Time taken: 200.254 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +----------------------------------------------------+-------------------+
# |                       title                        | publication_date  |
# +----------------------------------------------------+-------------------+
# | Rand McNally 2021 Motor Carriers' Road Atlas       | 22/06/2020        |
# | Rand McNally 2021 Deluxe Motor Carriers' Road Atlas | 22/06/2020        |
# +----------------------------------------------------+-------------------+
# 2 rows selected (204.199 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p1

# %% [markdown]
# ## Ejercicio Hive
# ## Parte 2
#
# Para este apartado he decidido usar el dataset de el Top 100 de la Lista Forbes (https://www.kaggle.com/darinhawley/forbes-celebrity-100-19992020)
#
# Este dataset consta de un solo fichero, el cual contiene 4 campos:
# - Name
# - Ocuppation
# - Rank
# - Year

# %%
#creamos un directorio para tratar los ficheros que vayamos generando y usando en local
! mkdir -p hive2
import os
os.chdir("hive2")

# %%
! pwd #Comprobamos que estamos en la ruta creada
# Out:
# /media/notebooks/hive2

# %%
# !ls ../hive2 #Comprobamos que los ficheros estan cargados en local
# Out:
# forbescelebrities.csv

# %%
 #Creamos los directorios en HDFS
! hadoop fs -mkdir /user/root/hive2 #Ruta principal
! hadoop fs -mkdir /user/root/hive2/forbescelebrities #Ruta fichero authors.csv

# %%
# Copiamos los ficheros a HDFS a sus respectivos directorios
! hadoop fs -put ../hive2/forbescelebrities.csv /user/root/hive2/forbescelebrities/
# Confirmamos que se hayan cargado previamente 
! hadoop fs -ls /user/root/hive2/forbescelebrities/
# Out:
# Found 1 items
# -rw-r--r--   3 root supergroup      72933 2021-11-14 12:01 /user/root/hive2/forbescelebrities/forbescelebrities.csv

# %%
# %%writefile createHiveEjP2.hql
#
# -- Creamos la BD
# CREATE DATABASE IF NOT EXISTS ej2_p2;
#
# -- Nos aseguramos de usar la BD creada
# USE ej2_p2;
#
# -- Creamos las tablas externas
# -- **CELEBRIDADES**
# CREATE EXTERNAL TABLE IF NOT EXISTS celebrities
#  (Name  STRING,
#   Year  INT,
#   Rank INT,
#   Occuppation STRING)
# ROW FORMAT DELIMITED FIELDS TERMINATED BY '\,'
# LOCATION '/user/root/hive2/forbescelebrities'
# TBLPROPERTIES ("skip.header.line.count"="1");
#
# --Comprobamos que se hayan creado las tablas correctamente
# SHOW TABLES;
# DESCRIBE celebrities;
# Out:
# Writing createHiveEjP2.hql

# %%
! beeline -u "jdbc:hive2://localhost:10000/" -f createHiveEjP2.hql
# Out:
# Connecting to jdbc:hive2://localhost:10000/
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# 0: jdbc:hive2://localhost:10000/>
# 0: jdbc:hive2://localhost:10000/> -- Creamos la BD
# 0: jdbc:hive2://localhost:10000/> CREATE DATABASE IF NOT EXISTS ej2_p2;
# INFO  : Compiling command(queryId=root_20211114120323_8969d9c5-049e-4598-92bf-32b432f41252): CREATE DATABASE IF NOT EXISTS ej2_p2
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=root_20211114120323_8969d9c5-049e-4598-92bf-32b432f41252); Time taken: 0.461 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114120323_8969d9c5-049e-4598-92bf-32b432f41252): CREATE DATABASE IF NOT EXISTS ej2_p2
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114120323_8969d9c5-049e-4598-92bf-32b432f41252); Time taken: 0.305 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (1.384 seconds)
# 0: jdbc:hive2://localhost:10000/>
# 0: jdbc:hive2://localhost:10000/> -- Nos aseguramos de usar la BD creada
# 0: jdbc:hive2://localhost:10000/> USE ej2_p2;
# INFO  : Compiling command(queryId=root_20211114120325_54a09d82-c3c9-48a4-b8ac-690b4ab46f38): USE ej2_p2
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=root_20211114120325_54a09d82-c3c9-48a4-b8ac-690b4ab46f38); Time taken: 0.144 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114120325_54a09d82-c3c9-48a4-b8ac-690b4ab46f38): USE ej2_p2
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114120325_54a09d82-c3c9-48a4-b8ac-690b4ab46f38); Time taken: 0.133 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (0.429 seconds)
# 0: jdbc:hive2://localhost:10000/>
# 0: jdbc:hive2://localhost:10000/> -- Creamos las tablas externas
# 0: jdbc:hive2://localhost:10000/> -- **CELEBRIDADES**
# s  jdbc:hive2://localhost:10000/> CREATE EXTERNAL TABLE IF NOT EXISTS celebritie
# . . . . . . . . . . . . . . . . >  (Name  STRING,
# . . . . . . . . . . . . . . . . >   Year  INT,
# . . . . . . . . . . . . . . . . >   Rank INT,
# . . . . . . . . . . . . . . . . >   Occuppation STRING)
#   . . . . . . . . . . . . . . . > ROW FORMAT DELIMITED FIELDS TERMINATED BY '\,'
# . . . . . . . . . . . . . . . . > LOCATION '/user/root/hive2/forbescelebrities'
# . . . . . . . . . . . . . . . . > TBLPROPERTIES ("skip.header.line.count"="1");
# INFO  : Compiling command(queryId=root_20211114120326_8b9ac473-237f-4ea3-aa91-d22e1abb3fd0): CREATE EXTERNAL TABLE IF NOT EXISTS celebrities
# (Name  STRING,
# Year  INT,
# Rank INT,
# Occuppation STRING)
# ROW FORMAT DELIMITED FIELDS TERMINATED BY '\,'
# LOCATION '/user/root/hive2/forbescelebrities'
# TBLPROPERTIES ("skip.header.line.count"="1")
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:null, properties:null)
# INFO  : Completed compiling command(queryId=root_20211114120326_8b9ac473-237f-4ea3-aa91-d22e1abb3fd0); Time taken: 0.168 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114120326_8b9ac473-237f-4ea3-aa91-d22e1abb3fd0): CREATE EXTERNAL TABLE IF NOT EXISTS celebrities
# (Name  STRING,
# Year  INT,
# Rank INT,
# Occuppation STRING)
# ROW FORMAT DELIMITED FIELDS TERMINATED BY '\,'
# LOCATION '/user/root/hive2/forbescelebrities'
# TBLPROPERTIES ("skip.header.line.count"="1")
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114120326_8b9ac473-237f-4ea3-aa91-d22e1abb3fd0); Time taken: 1.209 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# No rows affected (1.567 seconds)
# 0: jdbc:hive2://localhost:10000/>
# orredbc:hive2://localhost:10000/> --Comprobamos que se hayan creado las tablas c ctamente
# 0: jdbc:hive2://localhost:10000/> SHOW TABLES;
# INFO  : Compiling command(queryId=root_20211114120328_099b1c17-e3e3-45c6-a0f3-a7b4f4a21729): SHOW TABLES
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:tab_name, type:string, comment:from deserializer)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114120328_099b1c17-e3e3-45c6-a0f3-a7b4f4a21729); Time taken: 0.337 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114120328_099b1c17-e3e3-45c6-a0f3-a7b4f4a21729): SHOW TABLES
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114120328_099b1c17-e3e3-45c6-a0f3-a7b4f4a21729); Time taken: 0.2 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +--------------+
# |   tab_name   |
# +--------------+
# | celebrities  |
# +--------------+
# 1 row selected (1.306 seconds)
# 0: jdbc:hive2://localhost:10000/> DESCRIBE celebrities;
# INFO  : Compiling command(queryId=root_20211114120330_82f1338f-bbe1-4d98-aa0d-61676d57d053): DESCRIBE celebrities
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:col_name, type:string, comment:from deserializer), FieldSchema(name:data_type, type:string, comment:from deserializer), FieldSchema(name:comment, type:string, comment:from deserializer)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114120330_82f1338f-bbe1-4d98-aa0d-61676d57d053); Time taken: 0.38 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114120330_82f1338f-bbe1-4d98-aa0d-61676d57d053): DESCRIBE celebrities
# INFO  : Starting task [Stage-0:DDL] in serial mode
# INFO  : Completed executing command(queryId=root_20211114120330_82f1338f-bbe1-4d98-aa0d-61676d57d053); Time taken: 0.739 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +--------------+------------+----------+
# |   col_name   | data_type  | comment  |
# +--------------+------------+----------+
# | name         | string     |          |
# | year         | int        |          |
# | rank         | int        |          |
# | occuppation  | string     |          |
# +--------------+------------+----------+
# 4 rows selected (1.785 seconds)
# 0: jdbc:hive2://localhost:10000/>
# 0: jdbc:hive2://localhost:10000/> Closing: 0: jdbc:hive2://localhost:10000/

# %%
#Comprobamos que la tabla se haya cargado correctamente
! beeline -u "jdbc:hive2://localhost:10000/ej2_p2" -e "SELECT * FROM celebrities LIMIT 5;"
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p2
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114120453_6142d29d-3e1d-4368-8f3a-32310e66b820): SELECT * FROM celebrities LIMIT 5
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:celebrities.name, type:string, comment:null), FieldSchema(name:celebrities.year, type:int, comment:null), FieldSchema(name:celebrities.rank, type:int, comment:null), FieldSchema(name:celebrities.occuppation, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114120453_6142d29d-3e1d-4368-8f3a-32310e66b820); Time taken: 1.648 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114120453_6142d29d-3e1d-4368-8f3a-32310e66b820): SELECT * FROM celebrities LIMIT 5
# INFO  : Completed executing command(queryId=root_20211114120453_6142d29d-3e1d-4368-8f3a-32310e66b820); Time taken: 0.013 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +--------------------+-------------------+-------------------+--------------------------+
# |  celebrities.name  | celebrities.year  | celebrities.rank  | celebrities.occuppation  |
# +--------------------+-------------------+-------------------+--------------------------+
# | Kylie Jenner       | 2020              | 1                 | TV Personality           |
# | Kanye West         | 2020              | 2                 | Rapper/Producer          |
# | Roger Federer      | 2020              | 3                 | Tennis Player            |
# | Cristiano Ronaldo  | 2020              | 4                 | Soccer Player            |
# | Lionel Messi       | 2020              | 5                 | Soccer Player            |
# +--------------------+-------------------+-------------------+--------------------------+
# 5 rows selected (2.986 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p2

# %% [markdown]
# __Consulta 1: ¿Cuantos Deportistas hay en el top 100 cada año?Ordenados desde la actualidad al pasado__

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p2" -e "\
 SELECT COUNT(occuppation) AS count_players, year \
 FROM celebrities \
 WHERE occuppation LIKE '%Player' \
 GROUP BY year ORDER BY year DESC;"
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p2
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114120529_3d030777-f0c3-4abd-a9d9-20b2d976ef91): SELECT COUNT(occuppation) AS count_players, year   FROM celebrities   WHERE occuppation LIKE '%Player'   GROUP BY year ORDER BY year DESC
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:count_players, type:bigint, comment:null), FieldSchema(name:year, type:int, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114120529_3d030777-f0c3-4abd-a9d9-20b2d976ef91); Time taken: 1.912 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114120529_3d030777-f0c3-4abd-a9d9-20b2d976ef91): SELECT COUNT(occuppation) AS count_players, year   FROM celebrities   WHERE occuppation LIKE '%Player'   GROUP BY year ORDER BY year DESC
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = root_20211114120529_3d030777-f0c3-4abd-a9d9-20b2d976ef91
# INFO  : Total jobs = 2
# INFO  : Launching Job 1 out of 2
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0007
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0007/
# INFO  : Starting Job = job_1636883453227_0007, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0007/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0007
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 12:06:46,521 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 12:07:37,293 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 10.36 sec
# INFO  : 2021-11-14 12:08:20,275 Stage-1 map = 100%,  reduce = 67%, Cumulative CPU 17.11 sec
# INFO  : 2021-11-14 12:08:22,914 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 18.78 sec
# INFO  : MapReduce Total cumulative CPU time: 18 seconds 780 msec
# INFO  : Ended Job = job_1636883453227_0007
# INFO  : Launching Job 2 out of 2
# INFO  : Starting task [Stage-2:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0008
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0008/
# INFO  : Starting Job = job_1636883453227_0008, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0008/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0008
# INFO  : Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 12:09:29,093 Stage-2 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 12:10:11,414 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 6.1 sec
# INFO  : 2021-11-14 12:10:51,603 Stage-2 map = 100%,  reduce = 67%, Cumulative CPU 12.66 sec
# INFO  : 2021-11-14 12:10:54,035 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 13.66 sec
# INFO  : MapReduce Total cumulative CPU time: 13 seconds 660 msec
# INFO  : Ended Job = job_1636883453227_0008
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 18.78 sec   HDFS Read: 86222 HDFS Write: 558 SUCCESS
# INFO  : Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 13.66 sec   HDFS Read: 7860 HDFS Write: 527 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 32 seconds 440 msec
# INFO  : Completed executing command(queryId=root_20211114120529_3d030777-f0c3-4abd-a9d9-20b2d976ef91); Time taken: 326.321 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +----------------+-------+
# | count_players  | year  |
# +----------------+-------+
# | 24             | 2020  |
# | 24             | 2019  |
# | 22             | 2018  |
# | 20             | 2017  |
# | 26             | 2016  |
# | 20             | 2015  |
# | 13             | 2014  |
# | 11             | 2013  |
# | 13             | 2012  |
# | 16             | 2011  |
# | 12             | 2010  |
# | 12             | 2009  |
# | 12             | 2008  |
# | 11             | 2007  |
# | 13             | 2006  |
# | 17             | 2005  |
# | 19             | 2004  |
# | 18             | 2003  |
# | 18             | 2002  |
# | 17             | 2001  |
# | 16             | 2000  |
# | 29             | 1999  |
# +----------------+-------+
# 22 rows selected (329.056 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p2

# %% [markdown]
# __Consulta 2: Consultar cual es la Ocupación más mencionada y en que año__

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p2" -e "\
SELECT occuppation, year, COUNT(occuppation) AS count_occuppation \
FROM celebrities \
GROUP BY occuppation, year\
ORDER BY count_occuppation DESC\
LIMIT 1;"
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p2
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114121905_18ee2dfd-a0cb-4735-9d4b-974865babc69): SELECT occuppation, year, COUNT(occuppation) AS count_occuppation  FROM celebrities  GROUP BY occuppation, year ORDER BY count_occuppation DESC LIMIT 1
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:occuppation, type:string, comment:null), FieldSchema(name:year, type:int, comment:null), FieldSchema(name:count_occuppation, type:bigint, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114121905_18ee2dfd-a0cb-4735-9d4b-974865babc69); Time taken: 1.404 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114121905_18ee2dfd-a0cb-4735-9d4b-974865babc69): SELECT occuppation, year, COUNT(occuppation) AS count_occuppation  FROM celebrities  GROUP BY occuppation, year ORDER BY count_occuppation DESC LIMIT 1
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = root_20211114121905_18ee2dfd-a0cb-4735-9d4b-974865babc69
# INFO  : Total jobs = 2
# INFO  : Launching Job 1 out of 2
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0009
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0009/
# INFO  : Starting Job = job_1636883453227_0009, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0009/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0009
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 12:20:03,997 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 12:20:42,355 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 7.15 sec
# INFO  : 2021-11-14 12:21:16,750 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 13.76 sec
# INFO  : MapReduce Total cumulative CPU time: 13 seconds 760 msec
# INFO  : Ended Job = job_1636883453227_0009
# INFO  : Launching Job 2 out of 2
# INFO  : Starting task [Stage-2:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0010
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0010/
# INFO  : Starting Job = job_1636883453227_0010, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0010/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0010
# INFO  : Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 12:22:25,875 Stage-2 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 12:22:58,243 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 5.54 sec
# INFO  : 2021-11-14 12:23:34,877 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 12.51 sec
# INFO  : MapReduce Total cumulative CPU time: 12 seconds 510 msec
# INFO  : Ended Job = job_1636883453227_0010
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 13.76 sec   HDFS Read: 86219 HDFS Write: 21845 SUCCESS
# INFO  : Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 12.51 sec   HDFS Read: 29851 HDFS Write: 116 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 26 seconds 270 msec
# INFO  : Completed executing command(queryId=root_20211114121905_18ee2dfd-a0cb-4735-9d4b-974865babc69); Time taken: 271.851 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +--------------+-------+--------------------+
# | occuppation  | year  | count_occuppation  |
# +--------------+-------+--------------------+
# | Musician     | 2017  | 23                 |
# +--------------+-------+--------------------+
# 1 row selected (274.292 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p2

# %% [markdown]
# __Consulta 3: Cuales son las ocupaciones relacionadas con la TV__

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p2" -e "\
SELECT DISTINCT occuppation\
FROM celebrities\
WHERE occuppation LIKE '%TV%' ORDER BY occuppation"
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p2
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114122436_8e32ba47-adbc-421f-8786-d51aae1e58d2): SELECT DISTINCT occuppation FROM celebrities WHERE occuppation LIKE '%TV%' ORDER BY occuppation
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:occuppation, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114122436_8e32ba47-adbc-421f-8786-d51aae1e58d2); Time taken: 1.737 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114122436_8e32ba47-adbc-421f-8786-d51aae1e58d2): SELECT DISTINCT occuppation FROM celebrities WHERE occuppation LIKE '%TV%' ORDER BY occuppation
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = root_20211114122436_8e32ba47-adbc-421f-8786-d51aae1e58d2
# INFO  : Total jobs = 2
# INFO  : Launching Job 1 out of 2
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0011
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0011/
# INFO  : Starting Job = job_1636883453227_0011, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0011/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0011
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 12:25:38,554 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 12:26:23,738 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 8.52 sec
# INFO  : 2021-11-14 12:27:01,832 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 15.1 sec
# INFO  : MapReduce Total cumulative CPU time: 15 seconds 100 msec
# INFO  : Ended Job = job_1636883453227_0011
# INFO  : Launching Job 2 out of 2
# INFO  : Starting task [Stage-2:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0012
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0012/
# INFO  : Starting Job = job_1636883453227_0012, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0012/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0012
# INFO  : Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 12:28:00,688 Stage-2 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 12:28:38,803 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 6.03 sec
# INFO  : 2021-11-14 12:29:17,271 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 6.03 sec
# INFO  : MapReduce Total cumulative CPU time: 12 seconds 900 msec
# INFO  : Ended Job = job_1636883453227_0012
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 15.1 sec   HDFS Read: 84333 HDFS Write: 493 SUCCESS
# INFO  : Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 12.9 sec   HDFS Read: 7376 HDFS Write: 424 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 28 seconds 0 msec
# INFO  : Completed executing command(queryId=root_20211114122436_8e32ba47-adbc-421f-8786-d51aae1e58d2); Time taken: 283.315 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +-------------------------------+
# |          occuppation          |
# +-------------------------------+
# | Comedian/TV Host              |
# | Model/TV Host                 |
# | Reality TV                    |
# | TV Commercial Cast            |
# | TV Executives                 |
# | TV Host                       |
# | TV Host/Comedian              |
# | TV Personality                |
# | TV Personality/Businesswoman  |
# | TV Personality/Designer       |
# | TV Producer                   |
# | TV Show Cast                  |
# +-------------------------------+
# 12 rows selected (285.895 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p2

# %% [markdown]
# __Consulta 4: Top 5 de las celebridades que mas veces aparece en la lista__

# %%
! beeline -u "jdbc:hive2://localhost:10000/ej2_p2" -e "\
 SELECT COUNT(name) AS count_name, name\
 FROM celebrities \
 GROUP BY name \
 ORDER BY count_name DESC\
 LIMIT 5;"
# Out:
# Connecting to jdbc:hive2://localhost:10000/ej2_p2
# Connected to: Apache Hive (version 3.1.2)
# Driver: Hive JDBC (version 3.1.2)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=root_20211114123412_8a1719e5-9b1c-41d7-8f2f-364cb829d722): SELECT COUNT(name) AS count_name, name  FROM celebrities   GROUP BY name   ORDER BY count_name DESC  LIMIT 5
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Semantic Analysis Completed (retrial = false)
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:count_name, type:bigint, comment:null), FieldSchema(name:name, type:string, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=root_20211114123412_8a1719e5-9b1c-41d7-8f2f-364cb829d722); Time taken: 1.199 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=root_20211114123412_8a1719e5-9b1c-41d7-8f2f-364cb829d722): SELECT COUNT(name) AS count_name, name  FROM celebrities   GROUP BY name   ORDER BY count_name DESC  LIMIT 5
# WARN  : Hive-on-MR is deprecated in Hive 2 and may not be available in the future versions. Consider using a different execution engine (i.e. spark, tez) or using Hive 1.X releases.
# INFO  : Query ID = root_20211114123412_8a1719e5-9b1c-41d7-8f2f-364cb829d722
# INFO  : Total jobs = 2
# INFO  : Launching Job 1 out of 2
# INFO  : Starting task [Stage-1:MAPRED] in serial mode
# INFO  : Number of reduce tasks not specified. Estimated from input data size: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0013
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0013/
# INFO  : Starting Job = job_1636883453227_0013, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0013/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0013
# INFO  : Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 12:35:14,110 Stage-1 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 12:35:58,172 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 7.64 sec
# INFO  : 2021-11-14 12:36:36,385 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 14.62 sec
# INFO  : MapReduce Total cumulative CPU time: 14 seconds 620 msec
# INFO  : Ended Job = job_1636883453227_0013
# INFO  : Launching Job 2 out of 2
# INFO  : Starting task [Stage-2:MAPRED] in serial mode
# INFO  : Number of reduce tasks determined at compile time: 1
# INFO  : In order to change the average load for a reducer (in bytes):
# INFO  :   set hive.exec.reducers.bytes.per.reducer=<number>
# INFO  : In order to limit the maximum number of reducers:
# INFO  :   set hive.exec.reducers.max=<number>
# INFO  : In order to set a constant number of reducers:
# INFO  :   set mapreduce.job.reduces=<number>
# INFO  : number of splits:1
# INFO  : Submitting tokens for job: job_1636883453227_0014
# INFO  : Executing with tokens: []
# INFO  : The url to track the job: http://yarnmaster:8088/proxy/application_1636883453227_0014/
# INFO  : Starting Job = job_1636883453227_0014, Tracking URL = http://yarnmaster:8088/proxy/application_1636883453227_0014/
# INFO  : Kill Command = /app/hadoop-3.3.1/bin/mapred job  -kill job_1636883453227_0014
# INFO  : Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# INFO  : 2021-11-14 12:37:46,731 Stage-2 map = 0%,  reduce = 0%
# INFO  : 2021-11-14 12:38:36,463 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 6.2 sec
# INFO  : 2021-11-14 12:39:13,536 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 13.0 sec
# INFO  : MapReduce Total cumulative CPU time: 13 seconds 0 msec
# INFO  : Ended Job = job_1636883453227_0014
# INFO  : MapReduce Jobs Launched:
# INFO  : Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 14.62 sec   HDFS Read: 85730 HDFS Write: 19895 SUCCESS
# INFO  : Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 13.0 sec   HDFS Read: 27362 HDFS Write: 228 SUCCESS
# INFO  : Total MapReduce CPU Time Spent: 27 seconds 620 msec
# INFO  : Completed executing command(queryId=root_20211114123412_8a1719e5-9b1c-41d7-8f2f-364cb829d722); Time taken: 303.76 seconds
# INFO  : OK
# INFO  : Concurrency mode is disabled, not creating a lock manager
# +-------------+----------------+
# | count_name  |      name      |
# +-------------+----------------+
# | 22          | Tiger Woods    |
# | 22          | Howard Stern   |
# | 21          | Rush Limbaugh  |
# | 17          | Oprah Winfrey  |
# | 17          | LeBron James   |
# +-------------+----------------+
# 5 rows selected (305.737 seconds)
# Beeline version 3.1.2 by Apache Hive
# Closing: 0: jdbc:hive2://localhost:10000/ej2_p2
